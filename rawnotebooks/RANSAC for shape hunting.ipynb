# %%
points = np.load_points('p.ply') # Load your point cloud as a numpy array (N, 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-39ffe3426eb9> in <module>
# ----> 1 points = np.load_points('p.ply') # Load your point cloud as a numpy array (N, 3)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'load_points'

# %%
dir(points)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'cluster_dbscan',
#  'colors',
#  'compute_convex_hull',
#  'compute_mahalanobis_distance',
#  'compute_mean_and_covariance',
#  'compute_nearest_neighbor_distance',
#  'compute_point_cloud_distance',
#  'create_from_depth_image',
#  'create_from_rgbd_image',
#  'crop',
#  'dimension',
#  'estimate_normals',
#  'get_axis_aligned_bounding_box',
#  'get_center',
#  'get_geometry_type',
#  'get_max_bound',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'has_colors',
#  'has_normals',
#  'has_points',
#  'hidden_point_removal',
#  'is_empty',
#  'normalize_normals',
#  'normals',
#  'orient_normals_to_align_with_direction',
#  'orient_normals_towards_camera_location',
#  'paint_uniform_color',
#  'points',
#  'remove_non_finite_points',
#  'remove_radius_outlier',
#  'remove_statistical_outlier',
#  'rotate',
#  'scale',
#  'segment_plane',
#  'select_by_index',
#  'transform',
#  'translate',
#  'uniform_down_sample',
#  'voxel_down_sample',
#  'voxel_down_sample_and_trace']

# %%
points.paint_uniform_color(color = [[3, 1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-440c8489f6a6> in <module>
# ----> 1 points.paint_uniform_color(color = [[3, 1]])
#
# TypeError: paint_uniform_color(): incompatible function arguments. The following argument types are supported:
#     1. (self: open3d.open3d_pybind.geometry.PointCloud, color: numpy.ndarray[float64[3, 1]]) -> open3d.open3d_pybind.geometry.PointCloud
#
# Invoked with: geometry::PointCloud with 123992 points.; kwargs: color=[[3, 1]]

# %%
geo = points.get_geometry_type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-c935600a6170> in <module>
#       1 geo = points.get_geometry_type()
# ----> 2 geo[1]
#
# TypeError: 'open3d.open3d_pybind.geometry.Type' object is not subscriptable

# %%
import open3d as o3d
points = o3d.io.read_point_cloud("p.ply")

# %%
points.points
# Out:
# std::vector<Eigen::Vector3d> with 123992 elements.
# Use numpy.asarray() to access data.

# %%
p = np.asarray(points.points)
p.shape
# Out:
# (123992, 3)

# %%
import pyransac3d as pyrsc
import numpy as np 
import open3d as o3d

points = o3d.io.read_point_cloud("p.ply")

p = np.asarray(points.points)

cyc = pyrsc.Cylinder()

result = cyc.fit(p, thresh=0.2, maxIteration=100)

print('Center', result[0])
print('Axis',result[1])
print('Radius',result[2])
print('Inliers',result[3])

mask = result[3]

#This is the RANSAC fitted cylinder - play with threshold and iterations to get a better fit
x = p[mask]
plt.plot(x)

#To get the original unfitted point cloud
#plt.plot(p)
# Out:
# Center [ 1.80675746  1.58599312 -2.40820976]
# Axis [ 0.64233974 -0.76608637 -0.02261248]
# Radius 2.9767368536883905
# Inliers [    62     63     64 ... 123978 123979 123980]

# %%
dir(result)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
x = p[mask]
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x7f20f809e310>,
#  <matplotlib.lines.Line2D at 0x7f20f809e8e0>,
#  <matplotlib.lines.Line2D at 0x7f20f809e0a0>]

# %%
plt.plot(p)
# Out:
# [<matplotlib.lines.Line2D at 0x7f20f9df1be0>,
#  <matplotlib.lines.Line2D at 0x7f20f9df1f10>,
#  <matplotlib.lines.Line2D at 0x7f20f9df1e50>]

# %%
print(result[0])
# Out:
# [0.11728822 0.19925913 0.04457032]

# %%
plt.plot(result[3])

# %%
dir(points)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'cluster_dbscan',
#  'colors',
#  'compute_convex_hull',
#  'compute_mahalanobis_distance',
#  'compute_mean_and_covariance',
#  'compute_nearest_neighbor_distance',
#  'compute_point_cloud_distance',
#  'create_from_depth_image',
#  'create_from_rgbd_image',
#  'crop',
#  'dimension',
#  'estimate_normals',
#  'get_axis_aligned_bounding_box',
#  'get_center',
#  'get_geometry_type',
#  'get_max_bound',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'has_colors',
#  'has_normals',
#  'has_points',
#  'hidden_point_removal',
#  'is_empty',
#  'normalize_normals',
#  'normals',
#  'orient_normals_to_align_with_direction',
#  'orient_normals_towards_camera_location',
#  'paint_uniform_color',
#  'points',
#  'remove_non_finite_points',
#  'remove_radius_outlier',
#  'remove_statistical_outlier',
#  'rotate',
#  'scale',
#  'segment_plane',
#  'select_by_index',
#  'transform',
#  'translate',
#  'uniform_down_sample',
#  'voxel_down_sample',
#  'voxel_down_sample_and_trace']

# %%
center: Center of the cylinder np.array(1,3) which the cylinder axis is passing through.
axis: Vector describing cylinder's axis np.array(1,3).
radius: Radius of cylinder.
inliers: Inlier's index from the original point cloud.

# %%
points.dimension()
# Out:
# 3

# %%
vox = points.voxel_down_sample(voxel_size = 1000000)

# %%
bb = points.get_axis_aligned_bounding_box()
bb.get_center()
# Out:
# array([ 0.06574637, -0.03066564, -1.89680688])

# %%
dir(PointCloud.vox)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'cluster_dbscan',
#  'colors',
#  'compute_convex_hull',
#  'compute_mahalanobis_distance',
#  'compute_mean_and_covariance',
#  'compute_nearest_neighbor_distance',
#  'compute_point_cloud_distance',
#  'create_from_depth_image',
#  'create_from_rgbd_image',
#  'crop',
#  'dimension',
#  'estimate_normals',
#  'get_axis_aligned_bounding_box',
#  'get_center',
#  'get_geometry_type',
#  'get_max_bound',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'has_colors',
#  'has_normals',
#  'has_points',
#  'hidden_point_removal',
#  'is_empty',
#  'normalize_normals',
#  'normals',
#  'orient_normals_to_align_with_direction',
#  'orient_normals_towards_camera_location',
#  'paint_uniform_color',
#  'points',
#  'remove_non_finite_points',
#  'remove_radius_outlier',
#  'remove_statistical_outlier',
#  'rotate',
#  'scale',
#  'segment_plane',
#  'select_by_index',
#  'transform',
#  'translate',
#  'uniform_down_sample',
#  'voxel_down_sample',
#  'voxel_down_sample_and_trace']

# %%
import pyransac3d as pyrsc
import numpy as np 
#points = load_points(.) # Load your point cloud as a numpy array (N, 3)

points = np.random.rand(100, 3)

plane1 = pyrsc.Plane()
best_eq, best_inliers = plane1.fit(points, 0.01)
# Out:
# 100

# %%
dir(plane1)

# %%
cyc = pyrsc.Cylinder()

result = cyc.fit(p, thresh=0.2, maxIteration=100)

print('Center', result[0])
print('Axis',result[1])
print('Radius',result[2])
print('Inliers',result[3])

 

#This is the RANSAC fitted cylinder - play with threshold and iterations to get a better fit
x = points[mask]
plt.plot(x)

#To get the original unfitted point cloud
#plt.plot(p)

# %%
points.compute_mahalanobis_distance()
# Out:
# DoubleVector[2.92041, 2.91317, 2.90791, 2.9005, 2.89211, 2.88504, 2.87894, 2.87053, 2.86412, 2.85867, 2.85276, 2.95367, 2.94828, 2.93993, 2.9303, 2.92164, 2.91696, 2.91014, 2.90244, 2.89677, 2.88639, 2.88076, 2.87474, 2.86634, 2.85903, 2.85419, 2.8494, 2.8451, 2.97005, 2.96329, 2.95468, 2.94801, 2.8605, 2.85132, 2.8472, 2.84268, 2.84393, 2.98127, 2.9814, 2.89763, 2.878, 2.86389, 2.85088, 2.84665, 2.84495, 2.88709, 2.87573, 2.86579, 2.86171, 2.85297, 2.84909, 2.84618, 2.86093, 2.85763, 2.85759, 2.8545, 2.85527, 2.87037, 2.86386, 2.86574, 2.87155, 2.87016, 2.96652, 2.97464, 2.98567, 2.86797, 2.85803, 2.85702, 2.84964, 2.84341, 2.83389, 2.82403, 2.81691, 2.81077, 2.96232, 2.90435, 2.89921, 2.89401, 2.8913, 2.88802, 2.88182, 2.87529, 2.86785, 2.86114, 2.85208, 2.84493, 2.83671, 2.82902, 2.82267, 2.812, 2.8019, 2.96029, 2.93269, 2.92998, 2.92233, 2.91642, 2.91149, 2.90907, 2.90304, 2.89594, 2.87813, 2.8716, 2.86641, 2.85884, 2.85008, 2.84098, 2.83213, 2.82146, 2.81313, 2.80153, 2.79243, 2.97294, 2.95502, 2.94766, 2.94302, 2.83399, 2.82079, 2.81158, 2.80309, 2.79151, 2.84135, 2.82748, 2.8196, 2.81197, 2.80212, 3.00192, 2.854, 2.8432, 2.83411, 2.8228, 2.81935, 2.81049, 2.79981, 3.01545, 2.85035, 2.83664, 2.82701, 2.82775, 2.81871, 2.80666, 3.03057, 2.82973, 2.82508, 2.83532, 2.827, 3.04401, 2.85327, 2.84157, 2.95935, 2.96181, 2.85892, 2.80885, 2.80593, 2.79832, 2.78932, 2.78139, 2.77546, 2.90262, 2.89502, 2.84709, 2.84639, 2.83545, 2.833, 2.83012, 2.82547, 2.81746, 2.80899, 2.80183, 2.79396, 2.78722, 2.77913, 2.76807, 2.75821, 2.75121, 2.92395, 2.91526, 2.90783, 2.88412, 2.87283, 2.86531, 2.8582, 2.85225, 2.84899, 2.84416, 2.83712, 2.829, 2.81971, 2.81165, 2.80477, 2.79778, 2.78828, 2.77852, 2.77105, 2.76099, 2.74835, 2.73952, 2.93595, 2.92485, 2.89759, 2.89206, 2.88944, 2.78988, 2.78005, 2.76857, 2.76065, 2.74909, 2.9476, 2.93732, 2.78919, 2.77866, 2.76707, 2.75844, 2.74448, 2.95971, 2.95121, 2.79313, 2.78442, 2.77273, 2.76607, 2.75533, 2.97212, 2.96408, 2.7982, 2.7875, 2.77632, 2.77349, 2.76554, 2.98508, 2.97208, 2.80488, 2.79453, 2.78397, 2.78047, 2.77202, 3.00442, 2.99317, 2.80422, 2.79309, 2.78806, 2.78232, 3.01391, 2.99811, 2.98495, 2.80426, 2.79203, 2.7898, 2.77855, 3.0092, 2.9878, 2.9768, 2.78989, 2.91845, 2.90154, 2.82019, 2.80866, 2.79211, 2.74554, 2.74138, 2.84738, 2.83456, 2.78611, 2.78398, 2.77916, 2.77432, 2.7672, 2.75913, 2.75261, 2.7443, 2.73502, 2.72446, 2.71563, 2.70742, 2.86976, 2.86524, 2.82958, 2.81461, 2.80772, 2.80285, 2.79775, 2.79214, 2.78496, 2.77688, 2.76908, 2.75941, 2.75197, 2.74385, 2.73483, 2.72711, 2.71836, 2.70649, 2.69725, 2.88935, 2.88473, 2.87647, 2.83994, 2.83236, 2.82676, 2.82586, 2.74527, 2.73726, 2.72553, 2.7171, 2.70487, 2.69259, 2.8996, 2.89862, 2.73606, 2.72454, 2.71464, 2.70483, 2.91154, 2.90724, 2.7332, 2.72134, 2.71227, 2.70146, 2.92426, 2.91741, 2.9066, 2.74473, 2.73591, 2.72631, 2.71933, 2.70849, 2.94222, 2.93183, 2.92528, 2.75263, 2.74137, 2.73113, 2.72747, 2.71953, 2.95167, 2.94603, 2.93753, 2.76185, 2.74805, 2.73881, 2.73492, 2.72585, 2.96782, 2.95939, 2.947, 2.75845, 2.748, 2.74026, 2.7187, 2.9764, 2.97216, 2.95355, 2.96154, 2.76546, 2.75791, 2.74599, 2.73779, 2.74793, 2.99718, 2.9745, 2.94337, 2.93577, 2.7753, 2.76214, 2.75588, 2.76735, 2.76002, 2.75325, 2.90291, 2.87969, 2.89246, 2.8574, 2.86818, 2.84832, 2.85552, 2.84084, 2.83492, 2.85593, 2.82163, 2.8266, 2.79847, 2.80664, 2.81225, 2.86728, 2.81667, 2.85486, 2.86759, 2.87218, 2.84356, 2.85764, 2.86545, 2.87881, 2.87949, 2.88865, 2.90288, 2.84191, 2.87781, 2.87494, 2.88423, 2.77331, 2.764, 2.75211, 2.75687, 2.74297, 2.79365, 2.78761, 2.79251, 2.77221, 2.77122, 2.73169, 2.72629, 2.72608, 2.71807, 2.70933, 2.70096, 2.69194, 2.68095, 2.67279, 2.66565, 2.82826, 2.81163, 2.80853, 2.75854, 2.75663, 2.75139, 2.74574, 2.74125, 2.7383, 2.72706, 2.71734, 2.70782, 2.69969, 2.69184, 2.68501, 2.67469, 2.6638, 2.65338, 2.83301, 2.82678, 2.77899, 2.77371, 2.77004, 2.76829, 2.71931, 2.71117, 2.70269, 2.69467, 2.68271, 2.67352, 2.66574, 2.65415,  ...

# %%
plt.plot(best_eq)
plt.plot(best_inliers)

# %%
sph = pyrsc.Sphere()
center, radius, inliers = sph.fit(points, thresh=0.4)

# %%
cube = pyrsc.Cuboid()
result = cube.fit(p, thresh=10, maxIteration=100)
print('something', result[0])
print('inliers',result[1])
#print('Radius',result[2])
#print('Inliers',result[3])

# %%
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(x)

# %%
import open3d as o3d
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pyvista as pv
import vtk

# %%
print(pcd)
print(np.asarray(pcd.points))
o3d.visualization.draw_geometries([pcd])

# %%
dir(pcd)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'cluster_dbscan',
#  'colors',
#  'compute_convex_hull',
#  'compute_mahalanobis_distance',
#  'compute_mean_and_covariance',
#  'compute_nearest_neighbor_distance',
#  'compute_point_cloud_distance',
#  'create_from_depth_image',
#  'create_from_rgbd_image',
#  'crop',
#  'dimension',
#  'estimate_normals',
#  'get_axis_aligned_bounding_box',
#  'get_center',
#  'get_geometry_type',
#  'get_max_bound',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'has_colors',
#  'has_normals',
#  'has_points',
#  'hidden_point_removal',
#  'is_empty',
#  'normalize_normals',
#  'normals',
#  'orient_normals_to_align_with_direction',
#  'orient_normals_towards_camera_location',
#  'paint_uniform_color',
#  'points',
#  'remove_non_finite_points',
#  'remove_radius_outlier',
#  'remove_statistical_outlier',
#  'rotate',
#  'scale',
#  'segment_plane',
#  'select_by_index',
#  'transform',
#  'translate',
#  'uniform_down_sample',
#  'voxel_down_sample',
#  'voxel_down_sample_and_trace']

# %%
mesh = pv.read(pcd)
mesh.plot(screenshot='sewer')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-183-2e084b73bdd3> in <module>
# ----> 1 mesh = pv.read(pcd)
#       2 mesh.plot(screenshot='sewer')
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/pyvista/utilities/fileio.py in read(filename, attrs, file_format)
#     210     filename = os.path.abspath(os.path.expanduser(str(filename)))
#     211     if not os.path.isfile(filename):
# --> 212         raise FileNotFoundError('File ({}) not found'.format(filename))
#     213     ext = get_ext(filename)
#     214
#
# FileNotFoundError: File (/home/becode/dr-robin/sewereye/geometry::PointCloud with 48369 points.) not found

# %%
import trimesh
pcd = points
pcd.estimate_normals()

# estimate radius for rolling ball
distances = pcd.compute_nearest_neighbor_distance()
avg_dist = np.mean(distances)
radius = 1.5 * avg_dist   

mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
           pcd,
           o3d.utility.DoubleVector([radius, radius * 2]))

# create the triangular mesh with the vertices and faces from open3d
tri_mesh = trimesh.Trimesh(np.asarray(mesh.vertices), np.asarray(mesh.triangles),
                          vertex_normals=np.asarray(mesh.vertex_normals))

trimesh.convex.is_convex(tri_mesh)
# Out:
# False

# %%
trimesh.points.plot_points
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-c1893df2c029> in <module>
# ----> 1 tri_mesh.points.plot_points
#
# AttributeError: 'Trimesh' object has no attribute 'points'

# %%
tri_mesh.triangles
# Out:
# array([[[ 1.12165296,  0.19524662, -3.48920417],
#         [ 1.12316704,  0.20480658, -3.49019933],
#         [ 1.124946  ,  0.2032824 , -3.47046304]],
#
#        [[ 1.124946  ,  0.2032824 , -3.47046304],
#         [ 1.12270606,  0.19538581, -3.46923494],
#         [ 1.12165296,  0.19524662, -3.48920417]],
#
#        [[ 1.12270606,  0.19538581, -3.46923494],
#         [ 1.11081815,  0.1892291 , -3.46988368],
#         [ 1.12165296,  0.19524662, -3.48920417]],
#
#        ...,
#
#        [[-0.83022267, -0.57548678, -0.13563062],
#         [-0.80843753, -0.57555491, -0.13912529],
#         [-0.83325708, -0.55022228, -0.13755313]],
#
#        [[-0.90894175, -0.51189697, -0.14339826],
#         [-0.92199373, -0.51180363, -0.14439996],
#         [-0.886666  , -0.49591058, -0.14620125]],
#
#        [[-0.94240737, -0.327537  , -0.14689131],
#         [-0.9692238 , -0.3302027 , -0.14280982],
#         [-0.93603176, -0.31177795, -0.13888089]]])

# %%
plt.plot(tri_mesh.triangles)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-616c4c39f7d0> in <module>
# ----> 1 plt.plot(tri_mesh.triangles)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
# --> 402             raise ValueError(f"x and y can be no greater than 2-D, but have "
#     403                              f"shapes {x.shape} and {y.shape}")
#     404         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (109404,) and (109404, 3, 3)

# %%
x = p[mask]
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x7f20a69aef70>,
#  <matplotlib.lines.Line2D at 0x7f20a69bb0a0>,
#  <matplotlib.lines.Line2D at 0x7f20a69bb160>]

# %%
x.shape
# Out:
# (48369, 3)

# %%
p.shape
# Out:
# (123992, 3)

# %%
from pyntcloud import PyntCloud
PyntCloud.plot(points)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-7fab4b75f940> in <module>
#       1 from pyntcloud import PyntCloud
# ----> 2 PyntCloud.plot(points)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/pyntcloud/core_class.py in plot(self, backend, scene, width, height, background, mesh, use_as_color, initial_point_size, cmap, polylines, linewidth, return_scene, output_name, elev, azim, **kwargs)
#     762             return plot_with_threejs(self, **args)
#     763         elif backend == "pyvista":
# --> 764             return plot_with_pyvista(self, **args)
#     765         else:
#     766             raise NotImplementedError("{} backend is not supported".format(backend))
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/pyntcloud/plot/pyvista_backend.py in plot_with_pyvista(cloud, **kwargs)
#      52
#      53     # Get an RGB array using PyntCloud
# ---> 54     colors = get_colors(cloud, kwargs["use_as_color"], kwargs["cmap"])
#      55
#      56     poly_data = cloud.to_instance('pyvista', mesh=kwargs.pop("mesh", False))
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/pyntcloud/plot/common.py in get_colors(cloud, use_as_color, cmap)
#       4 def get_colors(cloud, use_as_color, cmap):
#       5     try:
# ----> 6         colors = cloud.points[use_as_color].values
#       7     except KeyError:
#       8         colors = None
#
# TypeError: __getitem__(): incompatible function arguments. The following argument types are supported:
#     1. (self: open3d.open3d_pybind.utility.Vector3dVector, s: slice) -> open3d.open3d_pybind.utility.Vector3dVector
#     2. (self: open3d.open3d_pybind.utility.Vector3dVector, arg0: int) -> numpy.ndarray[float64[3, 1]]
#
# Invoked with: std::vector<Eigen::Vector3d> with 123992 elements.
# Use numpy.asarray() to access data., ['red', 'green', 'blue']
#
# Did you forget to `#include <pybind11/stl.h>`? Or <pybind11/complex.h>,
# <pybind11/functional.h>, <pybind11/chrono.h>, etc. Some automatic
# conversions are optional and require extra headers to be included
# when compiling your pybind11 module.

# %%
z,x,y = x.nonzero()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-72e78ba8801b> in <module>
# ----> 1 z,x,y = x.nonzero()
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import pyransac3d as pyrsc
import numpy as np 
#points = load_points(.) # Load your point cloud as a numpy array (N, 3)

points = np.random.rand(100, 3)

cyc = pyrsc.Cylinder()

result = cyc.fit(points, thresh=0.2, maxIteration=10000)



'''
Find the parameters (axis and radius) to define a cylinder.

Arguments:

pts: 3D point cloud as a numpy array (N,3).
thresh: Threshold distance from the cylinder hull which is considered inlier.
maxIteration: Number of maximum iteration which RANSAC will loop over.
Returns:

center: Center of the cylinder np.array(1,3) which the cylinder axis is passing through.
axis: Vector describing cylinder's axis np.array(1,3).
radius: Radius of cylinder.
inliers: Inlier's index from the original point cloud.
'''
# Out:
# "\nFind the parameters (axis and radius) to define a cylinder.\n\nArguments:\n\npts: 3D point cloud as a numpy array (N,3).\nthresh: Threshold distance from the cylinder hull which is considered inlier.\nmaxIteration: Number of maximum iteration which RANSAC will loop over.\nReturns:\n\ncenter: Center of the cylinder np.array(1,3) which the cylinder axis is passing through.\naxis: Vector describing cylinder's axis np.array(1,3).\nradius: Radius of cylinder.\ninliers: Inlier's index from the original point cloud.\n"

# %%
inliers = result[3]

# %%
dir(cyc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'axis',
#  'center',
#  'fit',
#  'inliers',
#  'radius']

# %%
import matplotlib.pyplot as plt
xyz = points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xyz[inliers][:, 0], xyz[inliers][:, 1], xyz[inliers][:, 2], c='b',
           marker='o', label='Inlier data')
#ax.scatter(xyz[outliers][:, 0], xyz[outliers][:, 1], xyz[outliers][:, 2], c='r',
 #          marker='o', label='Outlier data')
ax.legend(loc='lower left')
plt.show()

# %%
#points = np.random.rand(100, 3)

cub = pyrsc.Cuboid()

result = cub.fit(points, thresh=0.2, maxIteration=10000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-ab5cebc9a257> in <module>
#       3 cub = pyrsc.Cuboid()
#       4
# ----> 5 result = cub.fit(points, thresh=0.2, maxIteration=10000)
#
# ~/dr-robin/sewereye/venv/lib/python3.8/site-packages/pyransac3d/cuboid.py in fit(self, pts, thresh, maxIteration)
#      36         ---
#      37         """
# ---> 38         n_points = pts.shape[0]
#      39         print(n_points)
#      40         best_eq = []
#
# AttributeError: 'open3d.open3d_pybind.geometry.PointCloud' object has no attribute 'shape'

# %%
dir(points)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'cluster_dbscan',
#  'colors',
#  'compute_convex_hull',
#  'compute_mahalanobis_distance',
#  'compute_mean_and_covariance',
#  'compute_nearest_neighbor_distance',
#  'compute_point_cloud_distance',
#  'create_from_depth_image',
#  'create_from_rgbd_image',
#  'crop',
#  'dimension',
#  'estimate_normals',
#  'get_axis_aligned_bounding_box',
#  'get_center',
#  'get_geometry_type',
#  'get_max_bound',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'has_colors',
#  'has_normals',
#  'has_points',
#  'hidden_point_removal',
#  'is_empty',
#  'normalize_normals',
#  'normals',
#  'orient_normals_to_align_with_direction',
#  'orient_normals_towards_camera_location',
#  'paint_uniform_color',
#  'points',
#  'remove_non_finite_points',
#  'remove_radius_outlier',
#  'remove_statistical_outlier',
#  'rotate',
#  'scale',
#  'segment_plane',
#  'select_by_index',
#  'transform',
#  'translate',
#  'uniform_down_sample',
#  'voxel_down_sample',
#  'voxel_down_sample_and_trace']

# %%
dbsc = points.cluster_dbscan(eps = 0.1, min_points = 10, print_progress = True)

# %%
bbox = points.get_axis_aligned_bounding_box()

# %%
dir(bbox)
# Out:
# ['HalfEdgeTriangleMesh',
#  'Image',
#  'LineSet',
#  'PointCloud',
#  'RGBDImage',
#  'TetraMesh',
#  'TriangleMesh',
#  'Type',
#  'Unspecified',
#  'VoxelGrid',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'color',
#  'create_from_points',
#  'dimension',
#  'get_axis_aligned_bounding_box',
#  'get_box_points',
#  'get_center',
#  'get_extent',
#  'get_geometry_type',
#  'get_half_extent',
#  'get_max_bound',
#  'get_max_extent',
#  'get_min_bound',
#  'get_oriented_bounding_box',
#  'get_point_indices_within_bounding_box',
#  'get_print_info',
#  'get_rotation_matrix_from_axis_angle',
#  'get_rotation_matrix_from_quaternion',
#  'get_rotation_matrix_from_xyz',
#  'get_rotation_matrix_from_xzy',
#  'get_rotation_matrix_from_yxz',
#  'get_rotation_matrix_from_yzx',
#  'get_rotation_matrix_from_zxy',
#  'get_rotation_matrix_from_zyx',
#  'is_empty',
#  'max_bound',
#  'min_bound',
#  'rotate',
#  'scale',
#  'transform',
#  'translate',
#  'volume']

# %%
bbox.max_bound()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5db9d3ea4af4> in <module>
# ----> 1 bbox.max_bound()
#
# TypeError: 'numpy.ndarray' object is not callable
